# %% [markdown]
# ### Visualizing letterboxd ratings for the report

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Load the data
data_filepath = "./lboxd_IDcoded.csv"
letterboxd = pd.read_csv(data_filepath)
letterboxd
# Out:
#          user                                        title  rating  movie_id
# 0         144                 Puss in Boots: The Last Wish     4.5     66829
# 1         144  The Guardians of the Galaxy Holiday Special     4.0     87522
# 2         144                             Dinosaur Hotel 2     2.0     25219
# 3         144                                Strange World     2.5     77851
# 4         144                 Zen - Grogu and Dust Bunnies     3.0    108598
# ...       ...                                          ...     ...       ...
# 1433485   290                               Newark Athlete     0.0     58824
# 1433486   290                        Roundhay Garden Scene     0.0     70149
# 1433487   290                   Sallie Gardner at a Gallop     0.0     70959
# 1433488   290                            This Land Is Mine     0.0     98758
# 1433489   290                                  Heavy Heads     0.0     37551
#
# [1433490 rows x 4 columns]

# %% [markdown]
# ### Plotting the distribution of counts of movies according to their number of ratings

# %% [markdown]
# #### Whole distribution

# %%
# Getting movie_counts
movie_counts = letterboxd['title'].value_counts()

# %%
# Plot the entire distribution of counts of movie ratings
plt.figure(figsize=(10, 6))
sns.histplot(movie_counts, bins=50, kde=True)
plt.title("Distribution of counts of movie ratings")

plt.xlabel("Number of ratings")
plt.ylabel("Number of movies")
plt.show()

# %% [markdown]
# #### Only the most relevant range

# %%
# Plot the distribution of counts of movie ratings (meaning how many times each movie was actually rated)
# Need to get the movie counts and then plot the distribution

# Calculate the Interquartile range (IQR)
Q1 = movie_counts.quantile(0.25)
Q3 = movie_counts.quantile(0.75)
IQR = Q3 - Q1

# Define the range for the x-axis
x_min = max(0, Q1 - 1.5 * IQR) # The lower bound is 0 or Q1 - 1.5*IQR, whichever is higher
x_max = Q3 + 1.5 * IQR # The upper bound is Q3 + 1.5*IQR

# %%
plt.figure(figsize=(10, 6))
sns.histplot(movie_counts)
plt.title("Distribution of counts of movie ratings")
plt.xlabel("Number of ratings")
plt.ylabel("Number of movies")
plt.xlim(x_min, x_max) # Set the limits for the x-axis
# Generate a list of x-axis tick locations and set them
x_ticks = np.arange(int(x_min), int(x_max) + 1)
plt.xticks(x_ticks)
plt.show()

# %%
# Print the number of movies with one rating vs the number of movies with more than one rating
print("Number of movies with one rating: ", sum(movie_counts == 1))
print("Number of movies with more than one rating: ", sum(movie_counts > 1))
# Out:
# Number of movies with one rating:  45105
# Number of movies with more than one rating:  63170

# %%
# Print the maximum number of movie ratings vs the minimum number of movie ratings
print("Maximum number of movie ratings: ", max(movie_counts))
print("Minimum number of movie ratings: ", min(movie_counts))
# Out:
# Maximum number of movie ratings:  509
# Minimum number of movie ratings:  1

# %% [markdown]
# ### Plotting percentage of movies with one rating vs movies with more than one rating

# %%
# Plot how much the movies with one rating influence the total number of ratings
# Calculate the percentage of ratings that come from movies with one rating
one_rating_movies = sum(movie_counts == 1)
more_than_one_rating_movies = sum(movie_counts > 1)
total_movies = one_rating_movies + more_than_one_rating_movies
one_rating_movies_percentage = one_rating_movies / total_movies * 100
more_than_one_rating_movies_percentage = more_than_one_rating_movies / total_movies * 100

plt.figure(figsize=(6, 6))
plt.pie([one_rating_movies_percentage, more_than_one_rating_movies_percentage], labels=["One rating", "More than one rating"], autopct='%1.1f%%')
plt.title("Percentage of movies with one rating vs movies with more than one rating")
plt.show()

# %% [markdown]
# ### Plotting percentage of ratings coming from movies that only have one rating vs the others

# %%
# From the entire number of ratings, plot how many ratings come from movies with one rating vs movies with more than one rating
one_rating_movies_ratings = sum(movie_counts[movie_counts == 1])
more_than_one_rating_movies_ratings = sum(movie_counts[movie_counts > 1])
total_ratings = one_rating_movies_ratings + more_than_one_rating_movies_ratings
one_rating_movies_ratings_percentage = one_rating_movies_ratings / total_ratings * 100
more_than_one_rating_movies_ratings_percentage = more_than_one_rating_movies_ratings / total_ratings * 100

plt.figure(figsize=(6, 6))
plt.pie([one_rating_movies_ratings_percentage, more_than_one_rating_movies_ratings_percentage], labels=["One rating", "More than one rating"], autopct='%1.1f%%')
plt.title("Percentage of ratings from movies with one rating vs movies with more than one rating")
plt.show()

# %%
# Plot the distribution of ratings in the dataset
plt.figure(figsize=(10, 6))
sns.histplot(letterboxd['rating'], bins=9, kde=True)
plt.title("Distribution of ratings in the dataset")
plt.xlabel("Rating")
plt.ylabel("Number of ratings")
plt.show()

# %%
# Plot the percentage of ratings of 0 against the rest of the ratings
zero_ratings = sum(letterboxd['rating'] == 0)
non_zero_ratings = sum(letterboxd['rating'] != 0)
total_ratings = zero_ratings + non_zero_ratings
zero_ratings_percentage = zero_ratings / total_ratings * 100
non_zero_ratings_percentage = non_zero_ratings / total_ratings * 100

plt.figure(figsize=(6, 6))
plt.pie([zero_ratings_percentage, non_zero_ratings_percentage], labels=["0", "Non-zero"], autopct='%1.1f%%')
plt.title("Percentage of ratings of 0 vs non-zero ratings") # 0 ratings don't exist in letterboxd and most likely mean movies that were watched by the user but not rated
plt.show()

# %% [markdown]
# ### Removing movies from dataset depending on their number of ratings
# - In order to get smaller samples of the dataset while keeping some of the structure of the original data.
# - Also allows us to get less disconnected subgraphs

# %%
sampled_dataframes = {}
dataframe_info = {}
movie_counts = letterboxd['title'].value_counts()
movie_range = range(0, 401, 10)

# For loop that goes from 0 to 401 and adds a dataframe to the sampled_dataframes dictionary that has removed the movies with the corresponding number of ratings
for i in movie_range:
    # Make a list of movies to keep and then filter the dataframe
    movies_to_keep = movie_counts[movie_counts > i].index
    sampled_lboxd = letterboxd[letterboxd['title'].isin(movies_to_keep)]
    sampled_dataframes[i] = sampled_lboxd
    
    # Print and store the number of movies in the sampled dataframe
    dataframe_info[i] = {}
    print("Dataframe with movies that have more than", i, "ratings")
    num_movies = len(sampled_dataframes[i]['title'].unique())
    dataframe_info[i]['num_movies'] = num_movies
    print("\tNumber of movies: ", num_movies)
    
    # Print and store the number of users in the sampled dataframe
    num_users = len(sampled_dataframes[i]['user'].unique())
    dataframe_info[i]['num_users'] = num_users
    print("\tNumber of users: ", num_users)
    
    # Print and store the number of ratings in the sampled dataframe
    num_ratings = len(sampled_dataframes[i])
    dataframe_info[i]['num_ratings'] = num_ratings
    print("\tNumber of ratings: ", num_ratings)
    
    # Print and store the percentage of ratings that come from movies with more than i ratings and less or equal to i ratings
    more_than_i_rating_movies_ratings = sum(movie_counts[movie_counts > i])
    less_or_equal_to_i_rating_movies_ratings = sum(movie_counts[movie_counts <= i])
    total_ratings = more_than_i_rating_movies_ratings + less_or_equal_to_i_rating_movies_ratings
    more_than_i_rating_movies_ratings_percentage = round(more_than_i_rating_movies_ratings / total_ratings * 100, 2)
    less_or_equal_to_i_rating_movies_ratings_percentage = round(less_or_equal_to_i_rating_movies_ratings / total_ratings * 100, 2)
    
    dataframe_info[i]['more_than_i_rating_movies_ratings_percentage'] = more_than_i_rating_movies_ratings_percentage
    print("\tPercentage of ratings from movies with more than", i, "ratings: ", more_than_i_rating_movies_ratings_percentage)
    dataframe_info[i]['less_or_equal_to_i_rating_movies_ratings_percentage'] = less_or_equal_to_i_rating_movies_ratings_percentage
    print("\tPercentage of ratings from movies with less or equal to", i, "ratings: ", less_or_equal_to_i_rating_movies_ratings_percentage)
    print()
# Out:
# Dataframe with movies that have more than 0 ratings
# 	Number of movies:  108275
# 	Number of users:  557
# 	Number of ratings:  1433490
# 	Percentage of ratings from movies with more than 0 ratings:  100.0
# 	Percentage of ratings from movies with less or equal to 0 ratings:  0.0
#
# Dataframe with movies that have more than 10 ratings
# 	Number of movies:  19190
# 	Number of users:  557
# 	Number of ratings:  1216907
# 	Percentage of ratings from movies with more than 10 ratings:  84.89
# 	Percentage of ratings from movies with less or equal to 10 ratings:  15.11
#
# Dataframe with movies that have more than 20 ratings
# 	Number of movies:  12516
# 	Number of users:  557
# 	Number of ratings:  1119246
# 	Percentage of ratings from movies with more than 20 ratings:  78.08
# 	Percentage of ratings from movies with less or equal to 20 ratings:  21.92
#
# Dataframe with movies that have more than 30 ratings
# 	Number of movies:  9524
# 	Number of users:  557
# 	Number of ratings:  1044542
# 	Percentage of ratings from movies with more than 30 ratings:  72.87
# 	Percentage of ratings from movies with less or equal to 30 ratings:  27.13
#
# Dataframe with movies that have more than 40 ratings
# 	Number of movies:  7778
# 	Number of users:  557
# 	Number of ratings:  983186
# 	Percentage of ratings from movies with more than 40 ratings:  68.59
# 	Percentage of ratings from movies with less or equal to 40 ratings:  31.41
#
# Dataframe with movies that have more than 50 ratings
# 	Number of movies:  6577
# 	Number of users:  557
# 	Number of ratings:  928972
# 	Percentage of ratings from movies with more than 50 ratings:  64.8
# 	Percentage of ratings from movies with less or equal to 50 ratings:  35.2
#
# Dataframe with movies that have more than 60 ratings
# 	Number of movies:  5662
# 	Number of users:  557
# 	Number of ratings:  878326
# 	Percentage of ratings from movies with more than 60 ratings:  61.27
# 	Percentage of ratings from movies with less or equal to 60 ratings:  38.73
#
# Dataframe with movies that have more than 70 ratings
# 	Number of movies:  4991
# 	Number of users:  557
# 	Number of ratings:  834487
# 	Percentage of ratings from movies with more than 70 ratings:  58.21
# 	Percentage of ratings from movies with less or equal to 70 ratings:  41.79
#
# Dataframe with movies that have more than 80 ratings
# 	Number of movies:  4394
# 	Number of users:  557
# 	Number of ratings:  789567
# 	Percentage of ratings from movies with more than 80 ratings:  55.08
# 	Percentage of ratings from movies with less or equal to 80 ratings:  44.92
#
# Dataframe with movies that have more than 90 ratings
# 	Number of movies:  3909
# 	Number of users:  557
# 	Number of ratings:  748103
# 	Percentage of ratings from movies with more than 90 ratings:  52.19
# 	Percentage of ratings from movies with less or equal to 90 ratings:  47.81
#
# Dataframe with movies that have more than 100 ratings
# 	Number of movies:  3517
# 	Number of users:  557
# 	Number of ratings:  710767
# 	Percentage of ratings from movies with more than 100 ratings:  49.58
# 	Percentage of ratings from movies with less or equal to 100 ratings:  50.42
#
# Dataframe with movies that have more than 110 ratings
# 	Number of movies:  3183
# 	Number of users:  557
# 	Number of ratings:  675620
# 	Percentage of ratings from movies with more than 110 ratings:  47.13
# 	Percentage of ratings from movies with less or equal to 110 ratings:  52.87
#
# Dataframe with movies that have more than 120 ratings
# 	Number of movies:  2891
# 	Number of users:  557
# 	Number of ratings:  641891
# 	Percentage of ratings from movies with more than 120 ratings:  44.78
# 	Percentage of ratings from movies with less or equal to 120 ratings:  55.22
#
# Dataframe with movies that have more than 130 ratings
# 	Number of movies:  2637
# 	Number of users:  557
# 	Number of ratings:  610007
# 	Percentage of ratings from movies with more than 130 ratings:  42.55
# 	Percentage of ratings from movies with less or equal to 130 ratings:  57.45
#
# Dataframe with movies that have more than 140 ratings
# 	Number of movies:  2400
# 	Number of users:  557
# 	Number of ratings:  577859
# 	Percentage of ratings from movies with more than 140 ratings:  40.31
# 	Percentage of ratings from movies with less or equal to 140 ratings:  59.69
#
# Dataframe with movies that have more than 150 ratings
# 	Number of movies:  2156
# 	Number of users:  557
# 	Number of ratings:  542423
# 	Percentage of ratings from movies with more than 150 ratings:  37.84
# 	Percentage of ratings from movies with less or equal to 150 ratings:  62.16
#
# Dataframe with movies that have more than 160 ratings
# 	Number of movies:  1966
# 	Number of users:  557
# 	Number of ratings:  512921
# 	Percentage of ratings from movies with more than 160 ratings:  35.78
# 	Percentage of ratings from movies with less or equal to 160 ratings:  64.22
#
# Dataframe with movies that have more than 170 ratings
# 	Number of movies:  1793
# 	Number of users:  557
# 	Number of ratings:  484264
# 	Percentage of ratings from movies with more than 170 ratings:  33.78
# 	Percentage of ratings from movies with less or equal to 170 ratings:  66.22
#
# Dataframe with movies that have more than 180 ratings
# 	Number of movies:  1645
# 	Number of users:  557
# 	Number of ratings:  458313
# 	Percentage of ratings from movies with more than 180 ratings:  31.97
# 	Percentage of ratings from movies with less or equal to 180 ratings:  68.03
#
# Dataframe with movies that have more than 190 ratings
# 	Number of movies:  1500
# 	Number of users:  557
# 	Number of ratings:  431441
# 	Percentage of ratings from movies with more than 190 ratings:  30.1
# 	Percentage of ratings from movies with less or equal to 190 ratings:  69.9
#
# Dataframe with movies that have more than 200 ratings
# 	Number of movies:  1373
# 	Number of users:  557
# 	Number of ratings:  406648
# 	Percentage of ratings from movies with more than 200 ratings:  28.37
# 	Percentage of ratings from movies with less or equal to 200 ratings:  71.63
#
# Dataframe with movies that have more than 210 ratings
# 	Number of movies:  1251
# 	Number of users:  557
# 	Number of ratings:  381630
# 	Percentage of ratings from movies with more than 210 ratings:  26.62
# 	Percentage of ratings from movies with less or equal to 210 ratings:  73.38
#
# Dataframe with movies that have more than 220 ratings
# 	Number of movies:  1152
# 	Number of users:  557
# 	Number of ratings:  360321
# 	Percentage of ratings from movies with more than 220 ratings:  25.14
# 	Percentage of ratings from movies with less or equal to 220 ratings:  74.86
#
# Dataframe with movies that have more than 230 ratings
# 	Number of movies:  1065
# 	Number of users:  557
# 	Number of ratings:  340758
# 	Percentage of ratings from movies with more than 230 ratings:  23.77
# 	Percentage of ratings from movies with less or equal to 230 ratings:  76.23
#
# Dataframe with movies that have more than 240 ratings
# 	Number of movies:  971
# 	Number of users:  557
# 	Number of ratings:  318635
# 	Percentage of ratings from movies with more than 240 ratings:  22.23
# 	Percentage of ratings from movies with less or equal to 240 ratings:  77.77
#
# Dataframe with movies that have more than 250 ratings
# 	Number of movies:  884
# 	Number of users:  557
# 	Number of ratings:  297284
# 	Percentage of ratings from movies with more than 250 ratings:  20.74
# 	Percentage of ratings from movies with less or equal to 250 ratings:  79.26
#
# Dataframe with movies that have more than 260 ratings
# 	Number of movies:  819
# 	Number of users:  557
# 	Number of ratings:  280699
# 	Percentage of ratings from movies with more than 260 ratings:  19.58
# 	Percentage of ratings from movies with less or equal to 260 ratings:  80.42
#
# Dataframe with movies that have more than 270 ratings
# 	Number of movies:  750
# 	Number of users:  557
# 	Number of ratings:  262352
# 	Percentage of ratings from movies with more than 270 ratings:  18.3
# 	Percentage of ratings from movies with less or equal to 270 ratings:  81.7
#
# Dataframe with movies that have more than 280 ratings
# 	Number of movies:  690
# 	Number of users:  557
# 	Number of ratings:  245814
# 	Percentage of ratings from movies with more than 280 ratings:  17.15
# 	Percentage of ratings from movies with less or equal to 280 ratings:  82.85
#
# Dataframe with movies that have more than 290 ratings
# 	Number of movies:  634
# 	Number of users:  557
# 	Number of ratings:  229831
# 	Percentage of ratings from movies with more than 290 ratings:  16.03
# 	Percentage of ratings from movies with less or equal to 290 ratings:  83.97
#
# Dataframe with movies that have more than 300 ratings
# 	Number of movies:  577
# 	Number of users:  557
# 	Number of ratings:  213009
# 	Percentage of ratings from movies with more than 300 ratings:  14.86
# 	Percentage of ratings from movies with less or equal to 300 ratings:  85.14
#
# Dataframe with movies that have more than 310 ratings
# 	Number of movies:  508
# 	Number of users:  557
# 	Number of ratings:  191922
# 	Percentage of ratings from movies with more than 310 ratings:  13.39
# 	Percentage of ratings from movies with less or equal to 310 ratings:  86.61
#
# Dataframe with movies that have more than 320 ratings
# 	Number of movies:  452
# 	Number of users:  557
# 	Number of ratings:  174248
# 	Percentage of ratings from movies with more than 320 ratings:  12.16
# 	Percentage of ratings from movies with less or equal to 320 ratings:  87.84
#
# Dataframe with movies that have more than 330 ratings
# 	Number of movies:  404
# 	Number of users:  557
# 	Number of ratings:  158621
# 	Percentage of ratings from movies with more than 330 ratings:  11.07
# 	Percentage of ratings from movies with less or equal to 330 ratings:  88.93
#
# Dataframe with movies that have more than 340 ratings
# 	Number of movies:  364
# 	Number of users:  556
# 	Number of ratings:  145172
# 	Percentage of ratings from movies with more than 340 ratings:  10.13
# 	Percentage of ratings from movies with less or equal to 340 ratings:  89.87
#
# Dataframe with movies that have more than 350 ratings
# 	Number of movies:  328
# 	Number of users:  556
# 	Number of ratings:  132754
# 	Percentage of ratings from movies with more than 350 ratings:  9.26
# 	Percentage of ratings from movies with less or equal to 350 ratings:  90.74
#
# Dataframe with movies that have more than 360 ratings
# 	Number of movies:  292
# 	Number of users:  556
# 	Number of ratings:  119963
# 	Percentage of ratings from movies with more than 360 ratings:  8.37
# 	Percentage of ratings from movies with less or equal to 360 ratings:  91.63
#
# Dataframe with movies that have more than 370 ratings
# 	Number of movies:  261
# 	Number of users:  556
# 	Number of ratings:  108614
# 	Percentage of ratings from movies with more than 370 ratings:  7.58
# 	Percentage of ratings from movies with less or equal to 370 ratings:  92.42
#
# Dataframe with movies that have more than 380 ratings
# 	Number of movies:  231
# 	Number of users:  556
# 	Number of ratings:  97362
# 	Percentage of ratings from movies with more than 380 ratings:  6.79
# 	Percentage of ratings from movies with less or equal to 380 ratings:  93.21
#
# Dataframe with movies that have more than 390 ratings
# 	Number of movies:  195
# 	Number of users:  556
# 	Number of ratings:  83497
# 	Percentage of ratings from movies with more than 390 ratings:  5.82
# 	Percentage of ratings from movies with less or equal to 390 ratings:  94.18
#
# Dataframe with movies that have more than 400 ratings
# 	Number of movies:  159
# 	Number of users:  556
# 	Number of ratings:  69261
# 	Percentage of ratings from movies with more than 400 ratings:  4.83
# 	Percentage of ratings from movies with less or equal to 400 ratings:  95.17

# %%
# Plot the number of movies, users and ratings for each dataframe in sampled_dataframes in different axes
fig, ax = plt.subplots(4, 1, figsize=(10, 18))
max_range = len(dataframe_info)+1

# Number of movies
num_movies = [dataframe_info[key]['num_movies'] for key in dataframe_info]
ax[0].bar(movie_range, num_movies)
ax[0].set_title("Number of movies in each dataframe")
ax[0].set_xlabel("Movies with more than x ratings")
ax[0].set_ylabel("Number of movies")

# Number of users
num_users = [dataframe_info[key]['num_users'] for key in dataframe_info]
ax[1].bar(movie_range, num_users)
# Restrict the y-axis around maximum and minimum values and ensure that the y-axis ticks are integers
ax[1].set_ylim(min(num_users) - 3, max(num_users) + 3)
ax[1].set_title("Number of users in each dataframe")
ax[1].set_xlabel("Movies with more than x ratings")
ax[1].set_ylabel("Number of users")

# Number of ratings
num_ratings = [dataframe_info[key]['num_ratings'] for key in dataframe_info]
ax[2].bar(movie_range, num_ratings)
ax[2].set_title("Number of ratings in each dataframe")
ax[2].set_xlabel("Movies with more than x ratings")
ax[2].set_ylabel("Number of ratings")

# Percentage of ratings from movies with more than x ratings
more_than_i_rating_movies_ratings_percentage = [dataframe_info[key]['more_than_i_rating_movies_ratings_percentage'] for key in dataframe_info]
ax[3].bar(movie_range, more_than_i_rating_movies_ratings_percentage)
ax[3].set_title("Percentage of ratings from movies with more than x ratings")
ax[3].set_xlabel("Movies with more than x ratings")
ax[3].set_ylabel("Percentage of ratings")
plt.show()

# %%
# Plot again but with lineplots this time
fig, ax = plt.subplots(4, 1, figsize=(10, 18))

# Number of movies
num_movies = [dataframe_info[key]['num_movies'] for key in dataframe_info]
ax[0].plot(movie_range, num_movies)
ax[0].set_title("Number of movies in each dataframe")
ax[0].set_xlabel("Movies with more than x ratings")
ax[0].set_ylabel("Number of movies")

# Number of users
num_users = [dataframe_info[key]['num_users'] for key in dataframe_info]
ax[1].plot(movie_range, num_users)
# Restrict the y-axis around maximum and minimum values and ensure that the y-axis ticks are integers
ax[1].set_ylim(min(num_users) - 3, max(num_users) + 3)
ax[1].set_title("Number of users in each dataframe")
ax[1].set_xlabel("Movies with more than x ratings")
ax[1].set_ylabel("Number of users")

# Number of ratings
num_ratings = [dataframe_info[key]['num_ratings'] for key in dataframe_info]
ax[2].plot(movie_range, num_ratings)
ax[2].set_title("Number of ratings in each dataframe")
ax[2].set_xlabel("Movies with more than x ratings")
ax[2].set_ylabel("Number of ratings")

# Percentage of ratings from movies with more than x ratings and less or equal to x ratings
more_than_i_rating_movies_ratings_percentage = [dataframe_info[key]['more_than_i_rating_movies_ratings_percentage'] for key in dataframe_info]
less_or_equal_to_i_rating_movies_ratings_percentage = [dataframe_info[key]['less_or_equal_to_i_rating_movies_ratings_percentage'] for key in dataframe_info]
ax[3].plot(movie_range, more_than_i_rating_movies_ratings_percentage, label="More than x ratings")
ax[3].plot(movie_range, less_or_equal_to_i_rating_movies_ratings_percentage, label="Less or equal to x ratings")
ax[3].set_title("Percentage of ratings from movies with more than x ratings and less or equal to x ratings")
ax[3].set_xlabel("Rating set")
ax[3].set_ylabel("Percentage of ratings")
ax[3].legend()
plt.show()

# %%
import networkx as nx

lboxd_no_single = sampled_dataframes[300]

# %%
# Convert the new_lboxd_data to a networkx bipartite graph with users and movies as nodes
G = nx.Graph()
G.add_nodes_from(lboxd_no_single['user'].unique(), bipartite=0)
G.add_nodes_from(lboxd_no_single['title'].unique(), bipartite=1)
G.add_edges_from(lboxd_no_single[['user', 'title']].values)

# %%
# Check the number of nodes and edges
print(nx.number_of_nodes(G))
print(nx.number_of_edges(G))

# Get the sets of nodes
users = {n for n, d in G.nodes(data=True) if d['bipartite'] == 0}
movies = {n for n, d in G.nodes(data=True) if d['bipartite'] == 1}

# Print the number of nodes in the sets
print(len(users))
print(len(movies))
# Out:
# 1134
# 213009
# 557
# 577

# %%
# Draw the graph
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, with_labels=False, node_size=5, width=.1)

# %%
import bilouvain_module as bl

node_types = {node:'top' if node in users else 'bottom' for node in G.nodes}
nx.set_node_attributes(G, node_types, name="node_type")

communities = bl.bilouvain(G)
# Out:
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4

# %%
# Print the communities
communities
# Out:
# {36: ['Guardians of the Galaxy',
#   'Logan',
#   'Manchester by the Sea',
#   'Ant-Man and the Wasp',
#   'Nocturnal Animals',
#   'Doctor Strange',
#   'Avengers: Infinity War',
#   'Guardians of the Galaxy Vol. 2',
#   'Iron Man 3',
#   'Three Billboards Outside Ebbing, Missouri',
#   'Love, Simon',
#   'You Were Never Really Here',
#   'X-Men: Apocalypse',
#   'Avengers: Age of Ultron',
#   'Terminator 2: Judgment Day',
#   'The Incredibles',
#   'Ant-Man',
#   'Saw',
#   'Thor',
#   'The Incredible Hulk',
#   'Paddington',
#   'Incredibles 2',
#   'Captain Marvel',
#   'Thor: The Dark World',
#   'Iron Man',
#   'Suicide Squad',
#   'The Godfather',
#   'Pinocchio',
#   'Bones and All',
#   'Kung Fu Panda',
#   'Iron Man 2',
#   'Forrest Gump',
#   'Thor: Ragnarok',
#   'mother!',
#   'Zombieland',
#   'The Dark Knight Rises',
#   'Captain America: Civil War',
#   'Solo: A Star Wars Story',
#   'The Empire Strikes Back',
#   'Spider-Man 2',
#   'Avatar: The Way of Water',
#   'Jojo Rabbit',
#   'Spider-Man: Homecoming',
#   'Spider-Man: Far From Home',
#   'Blade Runner 2049',
#   'Doctor Strange in the Multiverse of Madness',
#   'Baby Driver',
#   'Deadpool',
#   'Scott Pilgrim vs. the World',
#   'Inception',
#   'Eternals',
#   'The Suicide Squad',
#   'WALL·E',
#   'Shang-Chi and the Legend of the Ten Rings',
#   'Spider-Man: No Way Home',
#   'Black Widow',
#   'Thor: Love and Thunder',
#   "Don't Look Up",
#   'Top Gun',
#   'Scooby-Doo',
#   'Spider-Man',
#   'Arrival',
#   'This Is the End',
#   'Cars',
#   "Ferris Bueller's Day Off",
#   'Whiplash',
#   345,
#   356,
#   455,
#   330,
#   43,
#   271,
#   367,
#   401,
#   211,
#   372,
#   501,
#   470,
#   119,
#   88,
#   253,
#   538,
#   29,
#   479,
#   129,
#   322,
#   514,
#   231,
#   395,
#   80,
#   50,
#   83,
#   469,
#   411,
#   60,
#   'Rocketman',
#   'The Bling Ring',
#   '21 Jump Street',
#   'Shrek the Third',
#   'Enchanted',
#   'Luca',
#   'Easy A',
#   "The World's End",
#   'Shaun of the Dead',
#   'Swiss Army Man',
#   'Coraline',
#   'Monsters University',
#   'Punch-Drunk Love',
#   'The Black Phone',
#   'Indiana Jones and the Temple of Doom',
#   'Donnie Darko',
#   'Kingsman: The Secret Service',
#   'The Hunt',
#   'Coco',
#   'Frozen',
#   'E.T. the Extra-Terrestrial',
#   "Ocean's Eight",
#   'Kick-Ass',
#   'Big Hero 6',
#   'Paddington 2',
#   'Wonder Woman',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   'Harry Potter and the Half-Blood Prince',
#   'Dumbo',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'Lady and the Tramp',
#   'Pocahontas',
#   'Tarzan',
#   'Star Wars: Episode III -\xa0Revenge of the Sith',
#   'Star Wars: Episode I - The Phantom Menace',
#   'Before Midnight',
#   'Lilo & Stitch',
#   'The Lion King',
#   'Knives Out',
#   'The Little Mermaid',
#   'tick, tick...BOOM!',
#   "Howl's Moving Castle",
#   'American Psycho',
#   'My Neighbor Totoro',
#   'Moana',
#   'Spider-Man 3',
#   'Hercules',
#   'Glass Onion: A Knives Out Mystery',
#   'Star Wars: Episode II -\xa0Attack of the Clones',
#   'Before Sunrise',
#   'Beauty and the Beast',
#   'Shark Tale',
#   'Aladdin',
#   'Before Sunset',
#   'Encanto',
#   'Mulan',
#   "The Emperor's New Groove",
#   'Tangled',
#   'High School Musical',
#   359,
#   392,
#   402,
#   243,
#   531,
#   26,
#   91,
#   446,
#   385,
#   2,
#   387,
#   394,
#   523,
#   399,
#   527,
#   158,
#   415,
#   163,
#   292,
#   294,
#   551,
#   424,
#   299,
#   556,
#   46,
#   175,
#   48,
#   51,
#   52,
#   180,
#   184,
#   62,
#   64,
#   448,
#   454,
#   200,
#   210,
#   467,
#   340,
#   341,
#   344,
#   478,
#   353,
#   354,
#   108,
#   368,
#   369,
#   371,
#   117,
#   127,
#   130,
#   355,
#   482,
#   293,
#   105,
#   405,
#   150,
#   537,
#   223,
#   425,
#   194,
#   'Wreck-It Ralph',
#   'Freaky Friday',
#   'Jumanji: Welcome to the Jungle',
#   'Jurassic World',
#   'The Avengers',
#   'Justice League',
#   'A Quiet Place Part II',
#   'The Blair Witch Project',
#   'The Lord of the Rings: The Return of the King',
#   'Phantom Thread',
#   'The Perks of Being a Wallflower',
#   'Searching',
#   'Birdman or (The Unexpected Virtue of Ignorance)',
#   'Deadpool 2',
#   'The Cabin in the Woods',
#   'Sleeping Beauty',
#   'Titanic',
#   323,
#   201,
#   107,
#   459,
#   429,
#   492,
#   497,
#   498,
#   435,
#   24,
#   283,
#   92,
#   381,
#   31,
#   'Brave',
#   'Love Actually',
#   'Good Will Hunting',
#   'Moonlight',
#   'The Rocky Horror Picture Show',
#   'Room',
#   'We Need to Talk About Kevin',
#   'Zootopia',
#   'Groundhog Day',
#   'Spotlight',
#   'Carol',
#   "A Bug's Life",
#   'Monty Python and the Holy Grail',
#   'Shrek',
#   'Ratatouille',
#   'Memento',
#   'Eighth Grade',
#   'Up',
#   'The Devil Wears Prada',
#   'Snowpiercer',
#   'Superbad',
#   'Brokeback Mountain',
#   'Boogie Nights',
#   'Almost Famous',
#   'Captain America: The Winter Soldier',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   'Zoolander',
#   'Twilight',
#   'Harry Potter and the Order of the Phoenix',
#   'Grease',
#   'Eternal Sunshine of the Spotless Mind',
#   'Mean Girls',
#   "Jennifer's Body",
#   'Monsters, Inc.',
#   'Mamma Mia!',
#   'The Amazing Spider-Man',
#   'Ex Machina',
#   'Pitch Perfect',
#   'Harry Potter and the Prisoner of Azkaban',
#   'The Royal Tenenbaums',
#   'The Hunger Games',
#   'Sorry to Bother You',
#   'Neighbors',
#   'How to Train Your Dragon',
#   'How the Grinch Stole Christmas',
#   'The Conjuring',
#   'Now You See Me',
#   'Elf',
#   'The Godfather: Part II',
#   'Rushmore',
#   'Crazy Rich Asians',
#   'Fargo',
#   'The Princess Bride',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'The Lost World: Jurassic Park',
#   'The Parent Trap',
#   '13 Going on 30',
#   'Corpse Bride',
#   'Scream 4',
#   'Jurassic Park',
#   'Die Hard',
#   'When Harry Met Sally...',
#   'Scream 3',
#   'The Hunger Games: Catching Fire',
#   'Les Misérables',
#   'Game Night',
#   'Scream 2',
#   'The Host',
#   'Cinderella',
#   'The Hunger Games: Mockingjay - Part 1',
#   'Crazy, Stupid, Love.',
#   'Jurassic World: Fallen Kingdom',
#   'Airplane!',
#   147,
#   258,
#   262,
#   396,
#   13,
#   20,
#   22,
#   540,
#   541,
#   419,
#   548,
#   165,
#   295,
#   40,
#   169,
#   296,
#   423,
#   176,
#   434,
#   436,
#   182,
#   439,
#   56,
#   315,
#   316,
#   196,
#   77,
#   206,
#   215,
#   473,
#   348,
#   99,
#   363,
#   493,
#   373,
#   374,
#   376,
#   508,
#   510,
#   512,
#   8,
#   520,
#   144,
#   275,
#   149,
#   409,
#   412,
#   413,
#   414,
#   543,
#   417,
#   547,
#   553,
#   427,
#   300,
#   304,
#   432,
#   53,
#   440,
#   444,
#   317,
#   65,
#   326,
#   328,
#   75,
#   203,
#   460,
#   334,
#   461,
#   464,
#   209,
#   337,
#   466,
#   89,
#   480,
#   101,
#   486,
#   487,
#   488,
#   235,
#   118,
#   120,
#   506,
#   379,
#   125,
#   254,
#   187],
#  313: ['Gremlins',
#   'Beetlejuice',
#   'Midsommar',
#   'Us',
#   'Home Alone 2: Lost in New York',
#   'Alien',
#   'The Shining',
#   'Carrie',
#   'Jaws',
#   'Halloween',
#   'A Nightmare on Elm Street',
#   'Crash',
#   'Home Alone',
#   'Hereditary',
#   'A Quiet Place',
#   'The Thing',
#   "Rosemary's Baby",
#   'The Fly',
#   'The Florida Project',
#   'The Evil Dead',
#   'Ghostbusters',
#   'House',
#   '28 Days Later',
#   'Videodrome',
#   'The Addams Family',
#   'Charlie and the Chocolate Factory',
#   'Legally Blonde',
#   'The Texas Chain Saw Massacre',
#   'The Lighthouse',
#   'The Shape of Water',
#   'Pig',
#   'Old',
#   'The Witch',
#   'Annihilation',
#   "Pan's Labyrinth",
#   'The Twilight Saga: New Moon',
#   'Gravity',
#   'Jumanji',
#   'The Wolf of Wall Street',
#   'Batman Returns',
#   'Who Framed Roger Rabbit',
#   'Inherent Vice',
#   'The Departed',
#   'Titane',
#   'Clueless',
#   'The Wizard of Oz',
#   'It',
#   'Snow White and the Seven Dwarfs',
#   'Prisoners',
#   'Dune',
#   'The Master',
#   'Eyes Wide Shut',
#   'Gone Girl',
#   'Once Upon a Time… in Hollywood',
#   'Scarface',
#   'Perfect Blue',
#   'Crimes of the Future',
#   'The Babadook',
#   'Panic Room',
#   '(500) Days of Summer',
#   'Alice in Wonderland',
#   'Back to the Future Part II',
#   'Toy Story',
#   'Finding Nemo',
#   'Oldboy',
#   'Avengers: Endgame',
#   'Psycho',
#   'Blue Velvet',
#   'Toy Story 3',
#   'John Wick: Chapter 2',
#   'Toy Story 2',
#   'Back to the Future',
#   38,
#   1,
#   131,
#   389,
#   390,
#   518,
#   264,
#   526,
#   16,
#   274,
#   403,
#   148,
#   277,
#   406,
#   279,
#   533,
#   535,
#   285,
#   30,
#   545,
#   172,
#   430,
#   433,
#   311,
#   185,
#   186,
#   59,
#   190,
#   319,
#   70,
#   329,
#   458,
#   207,
#   335,
#   463,
#   338,
#   465,
#   87,
#   219,
#   349,
#   94,
#   484,
#   249,
#   232,
#   491,
#   236,
#   109,
#   110,
#   237,
#   494,
#   116,
#   507,
#   121,
#   123,
#   252,
#   509,
#   511,
#   291,
#   4,
#   76,
#   142,
#   21,
#   502,
#   313,
#   220,
#   400,
#   380,
#   96,
#   352,
#   515,
#   261,
#   391,
#   504,
#   361,
#   170,
#   525,
#   496,
#   503,
#   280,
#   346,
#   'Bodies Bodies Bodies',
#   'The Breakfast Club',
#   'Little Miss Sunshine',
#   'American Beauty',
#   'Scream',
#   'Shrek 2',
#   'Boyhood',
#   'The Silence of the Lambs',
#   'Mulholland Drive',
#   'Heathers',
#   'Stand by Me',
#   'Juno',
#   'Dead Poets Society',
#   '10 Things I Hate About You',
#   'Drive',
#   'Reservoir Dogs',
#   'School of Rock',
#   'Romeo + Juliet',
#   'Requiem for a Dream',
#   'The Hateful Eight',
#   'The Virgin Suicides',
#   'Pulp Fiction',
#   192,
#   450,
#   100,
#   420,
#   102,
#   166,
#   106,
#   234,
#   397,
#   529,
#   114,
#   145,
#   84,
#   177,
#   57,
#   159,
#   'No Country for Old Men',
#   'Kill Bill: Vol. 2',
#   'King Kong',
#   'The Revenant',
#   'Interstellar',
#   'Shutter Island',
#   'Heat',
#   'GoodFellas',
#   'Fresh',
#   "Ocean's Eleven",
#   'The Irishman',
#   'The Nice Guys',
#   'The Truman Show',
#   "Harry Potter and the Philosopher's Stone",
#   'Kill Bill: Vol. 1',
#   'Taxi Driver',
#   'Blade Runner',
#   'Rear Window',
#   'The Polar Express',
#   'Nightcrawler',
#   'Harry Potter and the Chamber of Secrets',
#   'Django Unchained',
#   'Inglourious Basterds',
#   'Avatar'],
#  354: ['Magnolia',
#   'Children of Men',
#   'Zodiac',
#   'Fight Club',
#   'The Batman',
#   'Soul',
#   'The Girl with the Dragon Tattoo',
#   'Suspiria',
#   'Nope',
#   'Nomadland',
#   'Se7en',
#   'Parasite',
#   'The Matrix',
#   'The Social Network',
#   'It Chapter Two',
#   'Nightmare Alley',
#   'Casino Royale',
#   'Inside Out',
#   'The Exorcist',
#   'Uncut Gems',
#   'Another Round',
#   'The Invisible Man',
#   'Elvis',
#   'Portrait of a Lady on Fire',
#   'Mank',
#   'The Killing of a Sacred Deer',
#   'Peter Pan',
#   "Don't Worry Darling",
#   'Joker',
#   'The Trial of the Chicago 7',
#   'The Dark Knight',
#   'The Menu',
#   'Last Night in Soho',
#   'The Banshees of Inisherin',
#   'Wonder Woman 1984',
#   'Promising Young Woman',
#   'Judas and the Black Messiah',
#   'TÁR',
#   'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   'Minari',
#   'Tenet',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '1917',
#   'John Wick: Chapter 3 - Parabellum',
#   'Star Wars: The Rise of Skywalker',
#   'The Matrix Resurrections',
#   'Sound of Metal',
#   'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#   'The Lord of the Rings: The Two Towers',
#   "I'm Thinking of Ending Things",
#   'The Power of the Dog',
#   'The Amazing Spider-Man 2',
#   'Star Wars: The Last Jedi',
#   'A Ghost Story',
#   'Fantastic Four',
#   'Man of Steel',
#   'Aquaman',
#   'John Wick',
#   'The Simpsons Movie',
#   'Toy Story 4',
#   'Prometheus',
#   'Star Wars: The Force Awakens',
#   'It Follows',
#   'Train to Busan',
#   'Venom',
#   'Everything Everywhere All at Once',
#   'Barbarian',
#   'Malignant',
#   'Turning Red',
#   'Candyman',
#   'Licorice Pizza',
#   'Top Gun: Maverick',
#   'Cruella',
#   'The Northman',
#   'The Green Knight',
#   'X',
#   'Pearl',
#   'Ready Player One',
#   128,
#   386,
#   516,
#   133,
#   6,
#   135,
#   265,
#   139,
#   140,
#   14,
#   15,
#   19,
#   404,
#   532,
#   282,
#   162,
#   35,
#   418,
#   37,
#   298,
#   171,
#   428,
#   49,
#   179,
#   181,
#   449,
#   195,
#   324,
#   451,
#   327,
#   333,
#   462,
#   336,
#   339,
#   472,
#   217,
#   476,
#   351,
#   357,
#   364,
#   365,
#   370,
#   500,
#   247,
#   382,
#   383,
#   442,
#   366,
#   388,
#   521,
#   11,
#   269,
#   398,
#   151,
#   152,
#   25,
#   27,
#   157,
#   542,
#   288,
#   42,
#   44,
#   309,
#   320,
#   197,
#   208,
#   468,
#   342,
#   483,
#   490,
#   240,
#   378,
#   146,
#   474,
#   68,
#   452,
#   362,
#   178,
#   445,
#   63,
#   536,
#   505,
#   539,
#   499,
#   257,
#   260,
#   5,
#   266,
#   268,
#   524,
#   270,
#   18,
#   276,
#   23,
#   407,
#   408,
#   28,
#   156,
#   284,
#   286,
#   32,
#   160,
#   546,
#   34,
#   36,
#   161,
#   416,
#   39,
#   421,
#   422,
#   426,
#   549,
#   552,
#   173,
#   555,
#   47,
#   544,
#   438,
#   55,
#   58,
#   66,
#   67,
#   198,
#   71,
#   456,
#   74,
#   202,
#   79,
#   214,
#   347,
#   93,
#   224,
#   225,
#   481,
#   227,
#   229,
#   233,
#   238,
#   112,
#   244,
#   246,
#   377,
#   122,
#   251,
#   124,
#   'Black Panther',
#   'The Disaster Artist',
#   'I, Tonya',
#   'Call Me by Your Name',
#   'West Side Story',
#   'Hustlers',
#   'Good Time',
#   'Catch Me If You Can',
#   'Mad Max: Fury Road',
#   'Thoroughbreds',
#   'Booksmart',
#   'A Star Is Born',
#   'Little Women',
#   'Palm Springs',
#   'The Favourite',
#   'Green Room',
#   'The Big Short',
#   '22 Jump Street',
#   'Raw',
#   'Lady Bird',
#   'The Lobster',
#   'The Hangover',
#   'The Big Sick',
#   'Popstar: Never Stop Never Stopping',
#   'The Worst Person in the World',
#   'Get Out',
#   'Spring Breakers',
#   'BlacKkKlansman',
#   'The Handmaiden',
#   'Her',
#   'Fantastic Mr. Fox',
#   'The Grand Budapest Hotel',
#   'Night at the Museum',
#   'La La Land',
#   'What We Do in the Shadows',
#   'Spider-Man: Into the Spider-Verse',
#   'Captain America: The First Avenger',
#   'The Farewell',
#   'The Lego Batman Movie',
#   'The French Dispatch',
#   'Amélie',
#   'Spirited Away',
#   '2001: A Space Odyssey',
#   'Shiva Baby',
#   'Bridesmaids',
#   'The Lego Movie',
#   'Spencer',
#   'The Edge of Seventeen',
#   'Dazed and Confused',
#   'Ad Astra',
#   'The Martian',
#   'The Sixth Sense',
#   'Black Swan',
#   'Marriage Story',
#   'First Reformed'],
#  498: ['First Man',
#   'Roma',
#   'Hail, Caesar!',
#   'In the Mood for Love',
#   'Finding Dory',
#   'Looper',
#   'Men in Black',
#   'One Hundred and One Dalmatians',
#   "Schindler's List",
#   'Batman v Superman: Dawn of Justice',
#   'Batman Begins',
#   'Mission: Impossible - Ghost Protocol',
#   'The Great Gatsby',
#   'Saving Private Ryan',
#   'The Prestige',
#   'Aliens',
#   'Dunkirk',
#   'Ford v Ferrari',
#   'The Hobbit: An Unexpected Journey',
#   'The Terminator',
#   'Jackie Brown',
#   'Space Jam',
#   'No Time to Die',
#   'Harry Potter and the Goblet of Fire',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'Bambi',
#   'Willy Wonka & the Chocolate Factory',
#   'Frances Ha',
#   'Edward Scissorhands',
#   'In Bruges',
#   'Shazam!',
#   'X2',
#   'Gladiator',
#   'Edge of Tomorrow',
#   'Ready or Not',
#   "It's a Wonderful Life",
#   'Mission: Impossible - Rogue Nation',
#   'Split',
#   'Do the Right Thing',
#   "Don't Breathe",
#   'Despicable Me',
#   'Slumdog Millionaire',
#   'The Karate Kid',
#   'Cloudy with a Chance of Meatballs',
#   'Isle of Dogs',
#   'Ice Age',
#   '10 Cloverfield Lane',
#   'Sicario',
#   'Kong: Skull Island',
#   'Skyfall',
#   'Matilda',
#   'Mission: Impossible - Fallout',
#   'Unbreakable',
#   'Under the Skin',
#   'Death Proof',
#   'Raiders of the Lost Ark',
#   'Moonrise Kingdom',
#   'Indiana Jones and the Last Crusade',
#   'Vertigo',
#   "Singin' in the Rain",
#   'Batman',
#   'Fantastic Beasts and Where to Find Them',
#   'X-Men',
#   'X-Men: First Class',
#   'X-Men: The Last Stand',
#   'Enemy',
#   'V for Vendetta',
#   'X-Men: Days of Future Past',
#   'Star Trek',
#   'Silver Linings Playbook',
#   'The Curious Case of Benjamin Button',
#   'Hugo',
#   "One Flew Over the Cuckoo's Nest",
#   'The Jungle Book',
#   'The Big Lebowski',
#   'There Will Be Blood',
#   'Trainspotting',
#   'Hot Fuzz',
#   'Anchorman: The Legend of Ron Burgundy',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'The Shawshank Redemption',
#   'American Hustle',
#   '12 Years a Slave',
#   'Burn After Reading',
#   'Mission: Impossible',
#   'Citizen Kane',
#   'Madagascar',
#   'Lost in Translation',
#   'Apocalypse Now',
#   '12 Angry Men',
#   'Being John Malkovich',
#   'The Usual Suspects',
#   'Okja',
#   'Léon: The Professional',
#   'The Graduate',
#   'Bohemian Rhapsody',
#   'Star Wars',
#   'Return of the Jedi',
#   'The Mummy',
#   'Rogue One: A Star Wars Story',
#   'Eraserhead',
#   'The Matrix Reloaded',
#   'The Matrix Revolutions',
#   'The Nightmare Before Christmas',
#   'Inside Llewyn Davis',
#   'Godzilla',
#   'Casablanca',
#   'The Life Aquatic with Steve Zissou',
#   'A Clockwork Orange',
#   'Full Metal Jacket',
#   'Princess Mononoke',
#   188,
#   513,
#   517,
#   7,
#   9,
#   522,
#   12,
#   530,
#   534,
#   33,
#   554,
#   45,
#   69,
#   78,
#   81,
#   82,
#   90,
#   97,
#   98,
#   103,
#   104,
#   111,
#   113,
#   134,
#   136,
#   137,
#   138,
#   141,
#   153,
#   154,
#   174,
#   183,
#   193,
#   204,
#   213,
#   216,
#   218,
#   222,
#   226,
#   228,
#   239,
#   241,
#   242,
#   245,
#   248,
#   255,
#   256,
#   259,
#   263,
#   272,
#   273,
#   278,
#   281,
#   287,
#   289,
#   290,
#   301,
#   303,
#   306,
#   310,
#   312,
#   314,
#   318,
#   321,
#   325,
#   331,
#   332,
#   358,
#   384,
#   393,
#   410,
#   437,
#   441,
#   443,
#   447,
#   453,
#   457,
#   471,
#   475,
#   485,
#   489,
#   495,
#   221,
#   17,
#   477,
#   0,
#   519,
#   10,
#   267,
#   528,
#   155,
#   164,
#   167,
#   41,
#   305,
#   308,
#   191,
#   199,
#   73,
#   212,
#   86,
#   343,
#   95,
#   3,
#   132,
#   143,
#   550,
#   168,
#   297,
#   302,
#   431,
#   307,
#   54,
#   189,
#   61,
#   72,
#   205,
#   85,
#   350,
#   230,
#   360,
#   115,
#   375,
#   250,
#   126]}

# %%
len(communities.keys())
# Out:
# 4
